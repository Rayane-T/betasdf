# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
history_50 = np.load('ex18_body_history_9_50.npy', allow_pickle=True)

# %%
plt.plot(history_50.item()['total_loss'], color ='r')
plt.title('Siren betasdf 50 epochs')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_100 = np.load('ex18_body_history_9_100.npy', allow_pickle=True)

# %%
plt.plot(history_100.item()['total_loss'], color ='r')
plt.title('Siren betasdf 100 epochs')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_500 = np.load('ex18_body_history_9_500.npy', allow_pickle=True)

# %%
plt.plot(history_500.item()['total_loss'], color ='r')
plt.title('Siren betasdf 500 epochs')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_999 = np.load('ex18_body_history_9_999.npy', allow_pickle=True)

# %%
plt.plot(history_999.item()['total_loss'], color ='r')
plt.title('Siren betasdf 999 epochs')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_1999 = np.load('ex18_body_history_9_1999.npy', allow_pickle=True)

# %%
plt.plot(history_1999.item()['total_loss'], color ='r')
plt.title('Siren betasdf 1999 epochs')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
