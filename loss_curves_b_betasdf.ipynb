# %%
# Voir les derniers avec 2000 epochs

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
history_50 = np.load('ex17_body_history_8_50.npy', allow_pickle=True)

# %%
print(history_50.item()['total_loss'])
# Out:
# [17.70097280950504, 15.869085634423534, 11.483692422060788, 3.763433967656951, 3.325367047825053, 3.033764895013434, 2.8522839190831135, 2.715617944752104, 2.60817926061003, 2.52149914075156, 2.453435615964667, 2.3963432466335624, 2.3489977928792145, 2.3139812576411614, 2.282902597989759, 2.2539638943200844, 2.232024660766945, 2.2110124054503286, 2.196206147538871, 2.1798408786757717, 2.162788926958825, 2.1482325103722535, 2.133248378670171, 2.12500761654053, 2.1123287803397353, 2.1042638992824316, 2.096795504310698, 2.089789113957533, 2.0955728450885562, 2.107200058162351, 2.1788371446541013, 2.235927693729173, 2.252845793466772, 2.2877711437036927, 2.240105175353526, 2.287133387003787, 2.296641235937803, 2.3012646693412377, 2.2945365203519907, 2.2861651184337926, 2.2902677093764883, 2.30714008903701, 2.324763846454546, 2.310614896882122, 2.289424840345463, 2.295561830985263, 2.3141009247496584, 2.3298647445703273, 2.32862234923128, 2.3119058664093175, 2.3188528561569046]

# %%
len(history_50.item()['total_loss'])
# Out:
# 51

# %%
plt.plot(history_50.item()['total_loss'], color ='r')
plt.title('8 layers simple beta sdf 50 epochs')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_100 = np.load('ex17_body_history_8_100.npy', allow_pickle=True)

# %%
len(history_100.item()['total_loss'])
# Out:
# 101

# %%
plt.plot(history_100.item()['total_loss'], color ='r')
plt.title('8 layers simple beta sdf 100 epochs')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_500 = np.load('ex17_body_history_8_500.npy', allow_pickle=True)

# %%
len(history_500.item()['total_loss'])
# Out:
# 501

# %%
plt.plot(history_500.item()['total_loss'], color ='r')
plt.ylim(0, 4)
plt.title('8 layers simple beta sdf 500 epochs')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_999 = np.load('ex17_body_history_8_999.npy', allow_pickle=True)

# %%
len(history_999.item()['total_loss'])
# Out:
# 1000

# %%
plt.plot(history_999.item()['total_loss'], color ='r')
plt.ylim(0, 4)
plt.title('8 layers simple beta sdf 1000 epochs')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_1999 = np.load('ex17_body_history_8_1999.npy', allow_pickle=True)

# %%
len(history_1999.item()['total_loss'])
# Out:
# 2000

# %%
plt.plot(history_1999.item()['total_loss'], color ='r')
plt.ylim(0, 4)
plt.title('8 layers simple beta sdf 2000 epochs')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
